# %%
import json
from textwrap import indent
import requests
# %pip install xmltodict
import xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
url = 'http://apis.data.go.kr/1741000/DisasterMsg3/getDisasterMsg1List'
params ={'serviceKey' : 'V7GqQuNPFr7BW9lTC/8+d6/8iu653AZHsgn/gKrciYV8AAEYM8yX1satHogBb5zNmjNP1VLo1xaHEEd9D4XckQ==', 'pageNo' : '1', 'numOfRows' : '5', 'type' : 'xml' }

response = requests.get(url, params=params)

xmlData = response.text
jsonStr = json.dumps(xmltodict.parse(xmlData))
dict = json.loads(jsonStr)
print(json.dumps(dict, indent=4, ensure_ascii=False))
# Out:
# {
#     "DisasterMsg": {
#         "head": {
#             "totalCount": "179184",
#             "numOfRows": "5",
#             "pageNo": "1",
#             "type": "XML",
#             "RESULT": {
#                 "resultCode": "INFO-0",
#                 "resultMsg": "NOMAL SERVICE"
#             }
#         },
#         "row": [
#             {
#                 "create_date": "2023/07/25 14:56:21",
#                 "location_id": "125",
#                 "location_name": "부산광역시 동래구",
#                 "md101_sn": "199758",
#                 "msg": "[부산경찰청] 동래구에서 목격된 지순남씨(여,70세)를 찾습니다 -148cm,45kg,꽃무늬셔츠,검정바지,검정신발,썬캡 vo.la/3U1rH / ☎182",
#                 "send_platform": "cbs"
#             },
#             {
#                 "create_date": "2023/07/25 14:55:51",
#                 "location_id": "80",
#                 "location_name": "경상북도 김천시",
#                 "md101_sn": "199757",
#                 "msg": "[김천시] 현재 호우경보중으로 시간당 50mm이상의 비가 국지적으로 내리고 있습니다. 외출 자제하시고 지하차도, 침수위험지역은 접근을 금지하여 주시기 바랍니다.",
#                 "send_platform": "cbs"
#             },
#             {
#                 "create_date": "2023/07/25 14:55:21",
#                 "location_id": "131",
#                 "location_name": "부산광역시 수영구",
#                 "md101_sn": "199756",
#                 "msg": "[부산경찰청] 수영구에서 배회중인 지순남씨(여,70세)를 찾습니다 -148cm,45kg,꽃무늬셔츠,검정바지,검정신발,썬캡 vo.la/3U1rH / ☎182",
#                 "send_platform": "cbs"
#             },
#             {
#                 "create_date": "2023/07/25 14:54:51",
#                 "location_id": "135",
#                 "location_name": "부산광역시 해운대구",
#                 "md101_sn": "199755",
#                 "msg": "[부산경찰청] 해운대구에서 실종된 지순남씨(여,70세)를 찾습니다 -148cm,45kg,꽃무늬셔츠,검정바지,검정신발,썬캡 vo.la/3U1rH / ☎182",
#                 "send_platform": "cbs"
#             },
#             {
#                 "create_date": "2023/07/25 14:46:13",
#                 "location_id": "80",
#                 "location_name": "경상북도 김천시",
#                 "md101_sn": "199754",
#                 "msg": "[행정안전부] 오늘 14시40분 경북(김천) 호우경보, 산사태ㆍ상습침수 등 위험지역 대피, 외출자제 등 안전에 주의바랍니다",
#                 "send_platform": "cbs"
#             }
#         ]
#     }
# }

# %%
url = 'http://apis.data.go.kr/1741000/DisasterMsg3/getDisasterMsg1List'
params ={'serviceKey' : 'V7GqQuNPFr7BW9lTC/8+d6/8iu653AZHsgn/gKrciYV8AAEYM8yX1satHogBb5zNmjNP1VLo1xaHEEd9D4XckQ==', 'pageNo' : '2', 'numOfRows' : '5', 'type' : 'xml' }

response = requests.get(url, params=params)

xmlData = response.text
jsonStr = json.dumps(xmltodict.parse(xmlData))
dict = json.loads(jsonStr)
print(json.dumps(dict, indent=4, ensure_ascii=False))
# Out:
# {
#     "DisasterMsg": {
#         "head": {
#             "totalCount": "179184",
#             "numOfRows": "5",
#             "pageNo": "2",
#             "type": "XML",
#             "RESULT": {
#                 "resultCode": "INFO-0",
#                 "resultMsg": "NOMAL SERVICE"
#             }
#         },
#         "row": [
#             {
#                 "create_date": "2023/07/25 14:42:21",
#                 "location_id": "80",
#                 "location_name": "경상북도 김천시",
#                 "md101_sn": "199753",
#                 "msg": "[김천시] 호우경보 발효, 시간당 50mm 이상의 집중호우 및 침수위험이 높은상태로 저지대, 지하차도, 하천변 등은 절대 접근을 금지합니다.",
#                 "send_platform": "cbs"
#             },
#             {
#                 "create_date": "2023/07/25 14:33:54",
#                 "location_id": "80",
#                 "location_name": "경상북도 김천시",
#                 "md101_sn": "199752",
#                 "msg": "[김천시] 호우주의보 발효, 시간당 30mm이상의 집중호우중으로 지하차도, 하천변, 산사태 위험지역 및 산림인접지역 접근 금지바랍니다.",
#                 "send_platform": "cbs"
#             },
#             {
#                 "create_date": "2023/07/25 14:16:11",
#                 "location_id": "198",
#                 "location_name": "전라남도 진도군",
#                 "md101_sn": "199751",
#                 "msg": "[진도군] 폭염주의보 발효 중, 낮시간 외출 및 야외 활동 자제, 충분한 수분섭취와 그늘 및 무더위 쉼터 이용 등으로 온열질환 예방하여 건강에 유의 바랍니다.",
#                 "send_platform": "cbs"
#             },
#             {
#                 "create_date": "2023/07/25 14:09:15",
#                 "location_id": "179",
#                 "location_name": "전라남도 전체",
#                 "md101_sn": "199750",
#                 "msg": "[전라남도]폭염주의보 발효 중. 논밭 등 야외활동 자제, 외출 시 모자나 양산 사용, 충분한 휴식과 수분 섭취, 안전수칙 준수 등 건강관리에 유의하시기 바랍니다.",
#                 "send_platform": "cbs"
#             },
#             {
#                 "create_date": "2023/07/25 14:00:10",
#                 "location_id": "238",
#                 "location_name": "충청북도 전체",
#                 "md101_sn": "199749",
#                 "msg": "[충청북도] 청주,옥천,진천,음성 폭염주의보 발효 중 ▲외출 및 야외 작업 자제▲무더위쉼터 이용▲폭염안전수칙(물, 그늘, 휴식) 준수 등 안전관리에 유의바랍니다.",
#                 "send_platform": "cbs"
#             }
#         ]
#     }
# }
