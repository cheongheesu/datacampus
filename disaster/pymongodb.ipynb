# %%
import pandas as pd
import csv
import numpy as np

# %% [markdown]
# # csv to json

# %%
import pandas as pd
import json

def csv_to_json(csv_path, json_path):
    # CSV 파일을 읽어옵니다.
    df = pd.read_csv(csv_path, encoding='cp949')

    # 데이터프레임을 JSON 형식으로 변환합니다.
    json_data = df.to_json(orient='records', lines=True)

    # JSON 파일로 저장합니다.
    with open(json_path, 'w') as f:
        f.write(json_data)

# 드라이브에 있는 CSV 파일의 경로와 JSON 파일로 저장할 경로를 지정합니다.
csv_file_path = '/content/drive/MyDrive/Colab_Notebooks/seoulplace.csv'
json_file_path = '/content/drive/MyDrive/Colab_Notebooks/seoulplace.json'

# 함수를 호출하여 CSV 파일을 JSON 파일로 변환합니다.
csv_to_json(csv_file_path, json_file_path)

# %%
import json

file_path = '/content/drive/MyDrive/Colab_Notebooks/seoulplace.json'

json_data = []
with open(file_path, 'r') as f:
    for line in f:
        # ensure_ascii=False로 설정하여 Unicode Escape Sequence 처리
        json_data.append(json.loads(line))

# indent를 기준으로 결과를 출력합니다.
print(json.dumps(json_data, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "관리번호": 47359,
#         "대피소 명칭": "화촌 경로당",
#         "대피소 상세주소": "화곡본동 105-382",
#         "면적": null,
#         "수용가능인원": 0,
#         "행정동 코드": 11500590,
#         "행정동 명칭": "화곡본동",
#         "비고": null
#     },
#     {
#         "관리번호": 47360,
#         "대피소 명칭": "화곡초등학교",
#         "대피소 상세주소": "화곡동 24-266",
#         "면적": null,
#         "수용가능인원": 0,
#         "행정동 코드": 11500590,
#         "행정동 명칭": "화곡본동",
#         "비고": null
#     },
#     {
#         "관리번호": 47361,
#         "대피소 명칭": "신길6동 주민센터",
#         "대피소 상세주소": "신길동 3741-11",
#         "면적": null,
#         "수용가능인원": 0,
#         "행정동 코드": 11560680,
#         "행정동 명칭": "신길6동",
#         "비고": null
#     },
#     {
#         "관리번호": 47362,
#         "대피소 명칭": "구로2동 주민센터",
#         "대피소 상세주소": "구로2동 704-12",
#         "면적": null,
#         "수용가능인원": 0,
#         "행정동 코드": 11530530,
#         "행정동 명칭": "구로2동",
#         "비고": null
#     },
#     {
#         "관리번호": 47363,
# ...

# %% [markdown]
# # pymongo 이용하여 mongodb 에 저장하기

# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.6/603.6 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
# ...

# %%
import pymongo
conn = pymongo.MongoClient('mongodb://localhost:27017')
